# %% [markdown]
# Reference: https://github.com/karpathy/ng-video-lecture

# %%
import torch

# %%
# hyperparameters

batch_size = 32 # how many independent sequences will we process in parallel
block_size = 8 # what is the maximum context length for prediction
eval_interval = 1000
max_iters = 50000
n_embd = 256
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'

# %%
# Read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("Length of dataset in characters: ", len(text))
# Out:
# Length of dataset in characters:  1115394

# %%
# Let's look at the first 1000 characters
print(text[:1000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
# Here are all the unique characters in the file
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print('Vocabulary size:', vocab_size)
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# Vocabulary size: 65

# %%
# Create a mapping from character to integer
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[ch] for ch in s] # encoder: takes a string and returns a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: takes a list of integers and returns a string

print(encode("hii there"))
print(decode(encode("hii there")))
# Out:
# [46, 47, 47, 1, 58, 46, 43, 56, 43]
# hii there

# %%
"""
Other mapping methods:
    1. Google: sentencepiece
               https://github.com/google/sentencepiece

    2. OpenAI: tiktoken
               https://github.com/openai/tiktoken

               import tiktoken
               enc = tiktoken.get_encoding("gpt2")
               enc.n_vocab
               enc.encode("hii there")
               enc.decode([71, 4178, 612])

"""
# Out:
# '\nOther mapping methods:\n    1. Google: sentencepiece\n               https://github.com/google/sentencepiece\n\n    2. OpenAI: tiktoken\n               https://github.com/openai/tiktoken\n\n               import tiktoken\n               enc = tiktoken.get_encoding("gpt2")\n               enc.n_vocab\n               enc.encode("hii there")\n               enc.decode([71, 4178, 612])\n\n'

# %%
# Let's now encode the entire text dataset and store it into a torch.Tensor
data = torch.tensor(encode(text), dtype=torch.long)
data = data.to(device)
print(data.shape, data.dtype)
print(data[:100]) # the 100 chatacters we looked at
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])

# %%
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% of the data will be used for training, rest for validation
train_data, valid_data = data[:n], data[n:]

# %%
valid_data.is_cuda
# Out:
# False

# %%
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target is {target}")

"""
Let the transformer predict next character by input 1 character.
And predict next character by input 2 characters.
And predict next character by input 3 characters.
And so on.
"""
# Out:
# when input is tensor([18]) the target is 47
# when input is tensor([18, 47]) the target is 56
# when input is tensor([18, 47, 56]) the target is 57
# when input is tensor([18, 47, 56, 57]) the target is 58
# when input is tensor([18, 47, 56, 57, 58]) the target is 1
# when input is tensor([18, 47, 56, 57, 58,  1]) the target is 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15]) the target is 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47]) the target is 58
# '\nLet the transformer predict next character by input 1 character.\nAnd predict next character by input 2 characters.\nAnd predict next character by input 3 characters.\nAnd so on.\n'

# %%
torch.manual_seed(1337)

def get_batch(split):
    # generate a small batch of inputs x and targets y
    if split == 'train':
        data = train_data
    else:
        data = valid_data

    ix = torch.randint(data.size(0) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix]) # (batch_size, block_size)
    y = torch.stack([data[i+1:i+block_size+1] for i in ix]) # shift 1 position to right

    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)

print('targets:')
print(yb.shape)
print(yb)

print('------')

for b in range(batch_size): # batch_dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b, t]
        print(f"when input is {context} the target is {target}")
# Out:
# inputs:
# torch.Size([32, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54],
#         [57, 43, 60, 43, 52,  1, 63, 43],
#         [60, 43, 42,  8,  0, 25, 63,  1],
#         [56, 42,  5, 57,  1, 57, 39, 49],
#         [43, 57, 58, 63,  6,  1, 58, 46],
#         [43,  1, 51, 39, 63,  1, 40, 43],
#         [58, 46, 43,  1, 43, 39, 56, 57],
#         [39, 58, 47, 53, 52, 12,  1, 37],
#         [53, 56, 43,  1, 21,  1, 41, 39],
#         [50, 39, 52, 63,  1, 47, 58, 57],
#         [56, 53, 63,  1, 42, 47, 42,  1],
#         [39, 51,  1, 39, 44, 56, 39, 47],
#         [17, 24, 21, 38, 13, 14, 17, 32],
#         [ 1, 39, 52, 42,  1, 45, 43, 50],
#         [ 1, 58, 46, 39, 58,  1, 42, 53],
#         [ 1, 61, 53, 59, 50, 42,  1, 21],
#         [59, 57, 40, 39, 52, 42,  1, 40],
#         [52, 42,  8,  0,  0, 23, 21, 26],
#         [45, 53, 42, 57,  0, 23, 43, 43],
#         [52,  1, 61, 39, 57,  1, 51, 53],
#         [39, 49, 12,  1, 27,  1, 58, 56],
#         [53, 44,  1, 57, 54, 43, 43, 41],
#         [57, 53, 52, 57,  8,  0,  0, 25],
#         [ 1, 42, 43, 44, 43, 41, 58,  1],
#         [21,  1, 61, 39, 52, 42, 43, 56],
#         [43, 43, 51,  5, 42,  1, 40, 59],
#         [45, 50, 63,  1, 52, 53, 61, 12],
#         [52, 53, 58,  8,  0, 25, 63,  1],
#         [53, 58,  6,  1, 51, 63,  1, 50]])
# targets:
# torch.Size([32, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39],
#         [43, 60, 43, 52,  1, 63, 43, 39],
#         [43, 42,  8,  0, 25, 63,  1, 45],
#         [42,  5, 57,  1, 57, 39, 49, 43],
#         [57, 58, 63,  6,  1, 58, 46, 47],
#         [ 1, 51, 39, 63,  1, 40, 43,  1],
#         [46, 43,  1, 43, 39, 56, 57, 10],
#         [58, 47, 53, 52, 12,  1, 37, 53],
#         [56, 43,  1, 21,  1, 41, 39, 51],
#         [39, 52, 63,  1, 47, 58, 57, 43],
#         [53, 63,  1, 42, 47, 42,  1, 57],
#         [51,  1, 39, 44, 56, 39, 47, 42],
#         [24, 21, 38, 13, 14, 17, 32, 20],
#         [39, 52, 42,  1, 45, 43, 50, 42],
#         [58, 46, 39, 58,  1, 42, 53,  1],
#         [61, 53, 59, 50, 42,  1, 21,  1],
#         [57, 40, 39, 52, 42,  1, 40, 47],
#         [42,  8,  0,  0, 23, 21, 26, 19],
#         [53, 42, 57,  0, 23, 43, 43, 54],
#         [ 1, 61, 39, 57,  1, 51, 53, 56],
#         [49, 12,  1, 27,  1, 58, 56, 39],
#         [44,  1, 57, 54, 43, 43, 41, 46],
#         [53, 52, 57,  8,  0,  0, 25, 17],
#         [42, 43, 44, 43, 41, 58,  1, 53],
#         [ 1, 61, 39, 52, 42, 43, 56,  6],
#         [43, 51,  5, 42,  1, 40, 59, 56],
#         [50, 63,  1, 52, 53, 61, 12,  0],
#         [53, 58,  8,  0, 25, 63,  1, 61],
#         [58,  6,  1, 51, 63,  1, 50, 53]])
# ------
# when input is tensor([24]) the target is 43
# when input is tensor([24, 43]) the target is 58
# when input is tensor([24, 43, 58]) the target is 5
# when input is tensor([24, 43, 58,  5]) the target is 57
# when input is tensor([24, 43, 58,  5, 57]) the target is 1
# when input is tensor([24, 43, 58,  5, 57,  1]) the target is 46
# when input is tensor([24, 43, 58,  5, 57,  1, 46]) the target is 43
# when input is tensor([24, 43, 58,  5, 57,  1, 46, 43]) the target is 39
# when input is tensor([44]) the target is 53
# when input is tensor([44, 53]) the target is 56
# when input is tensor([44, 53, 56]) the target is 1
# when input is tensor([44, 53, 56,  1]) the target is 58
# when input is tensor([44, 53, 56,  1, 58]) the target is 46
# when input is tensor([44, 53, 56,  1, 58, 46]) the target is 39
# when input is tensor([44, 53, 56,  1, 58, 46, 39]) the target is 58
# when input is tensor([44, 53, 56,  1, 58, 46, 39, 58]) the target is 1
# when input is tensor([52]) the target is 58
# when input is tensor([52, 58]) the target is 1
# when input is tensor([52, 58,  1]) the target is 58
# when input is tensor([52, 58,  1, 58]) the target is 46
# when input is tensor([52, 58,  1, 58, 46]) the target is 39
# when input is tensor([52, 58,  1, 58, 46, 39]) the target is 58
# when input is tensor([52, 58,  1, 58, 46, 39, 58]) the target is 1
# when input is tensor([52, 58,  1, 58, 46, 39, 58,  1]) the target is 46
# when input is tensor([25]) the target is 17
# when input is tensor([25, 17]) the target is 27
# when input is tensor([25, 17, 27]) the target is 10
# when input is tensor([25, 17, 27, 10]) the target is 0
# when input is tensor([25, 17, 27, 10,  0]) the target is 21
# when input is tensor([25, 17, 27, 10,  0, 21]) the target is 1
# when input is tensor([25, 17, 27, 10,  0, 21,  1]) the target is 54
# when input is tensor([25, 17, 27, 10,  0, 21,  1, 54]) the target is 39
# when input is tensor([57]) the target is 43
# when input is tensor([57, 43]) the target is 60
# when input is tensor([57, 43, 60]) the target is 43
# when input is tensor([57, 43, 60, 43]) the target is 52
# when input is tensor([57, 43, 60, 43, 52]) the target is 1
# when input is tensor([57, 43, 60, 43, 52,  1]) the target is 63
# when input is tensor([57, 43, 60, 43, 52,  1, 63]) the target is 43
# when input is tensor([57, 43, 60, 43, 52,  1, 63, 43]) the target is 39
# when input is tensor([60]) the target is 43
# when input is tensor([60, 43]) the target is 42
# when input is tensor([60, 43, 42]) the target is 8
# when input is tensor([60, 43, 42,  8]) the target is 0
# when input is tensor([60, 43, 42,  8,  0]) the target is 25
# when input is tensor([60, 43, 42,  8,  0, 25]) the target is 63
# when input is tensor([60, 43, 42,  8,  0, 25, 63]) the target is 1
# when input is tensor([60, 43, 42,  8,  0, 25, 63,  1]) the target is 45
# when input is tensor([56]) the target is 42
# when input is tensor([56, 42]) the target is 5
# when input is tensor([56, 42,  5]) the target is 57
# when input is tensor([56, 42,  5, 57]) the target is 1
# when input is tensor([56, 42,  5, 57,  1]) the target is 57
# when input is tensor([56, 42,  5, 57,  1, 57]) the target is 39
# when input is tensor([56, 42,  5, 57,  1, 57, 39]) the target is 49
# when input is tensor([56, 42,  5, 57,  1, 57, 39, 49]) the target is 43
# when input is tensor([43]) the target is 57
# when input is tensor([43, 57]) the target is 58
# when input is tensor([43, 57, 58]) the target is 63
# when input is tensor([43, 57, 58, 63]) the target is 6
# when input is tensor([43, 57, 58, 63,  6]) the target is 1
# when input is tensor([43, 57, 58, 63,  6,  1]) the target is 58
# when input is tensor([43, 57, 58, 63,  6,  1, 58]) the target is 46
# when input is tensor([43, 57, 58, 63,  6,  1, 58, 46]) the target is 47
# when input is tensor([43]) the target is 1
# when input is tensor([43,  1]) the target is 51
# when input is tensor([43,  1, 51]) the target is 39
# when input is tensor([43,  1, 51, 39]) the target is 63
# when input is tensor([43,  1, 51, 39, 63]) the target is 1
# when input is tensor([43,  1, 51, 39, 63,  1]) the target is 40
# when input is tensor([43,  1, 51, 39, 63,  1, 40]) the target is 43
# when input is tensor([43,  1, 51, 39, 63,  1, 40, 43]) the target is 1
# when input is tensor([58]) the target is 46
# when input is tensor([58, 46]) the target is 43
# when input is tensor([58, 46, 43]) the target is 1
# when input is tensor([58, 46, 43,  1]) the target is 43
# when input is tensor([58, 46, 43,  1, 43]) the target is 39
# when input is tensor([58, 46, 43,  1, 43, 39]) the target is 56
# when input is tensor([58, 46, 43,  1, 43, 39, 56]) the target is 57
# when input is tensor([58, 46, 43,  1, 43, 39, 56, 57]) the target is 10
# when input is tensor([39]) the target is 58
# when input is tensor([39, 58]) the target is 47
# when input is tensor([39, 58, 47]) the target is 53
# when input is tensor([39, 58, 47, 53]) the target is 52
# when input is tensor([39, 58, 47, 53, 52]) the target is 12
# when input is tensor([39, 58, 47, 53, 52, 12]) the target is 1
# when input is tensor([39, 58, 47, 53, 52, 12,  1]) the target is 37
# when input is tensor([39, 58, 47, 53, 52, 12,  1, 37]) the target is 53
# when input is tensor([53]) the target is 56
# when input is tensor([53, 56]) the target is 43
# when input is tensor([53, 56, 43]) the target is 1
# when input is tensor([53, 56, 43,  1]) the target is 21
# when input is tensor([53, 56, 43,  1, 21]) the target is 1
# when input is tensor([53, 56, 43,  1, 21,  1]) the target is 41
# when input is tensor([53, 56, 43,  1, 21,  1, 41]) the target is 39
# when input is tensor([53, 56, 43,  1, 21,  1, 41, 39]) the target is 51
# when input is tensor([50]) the target is 39
# when input is tensor([50, 39]) the target is 52
# when input is tensor([50, 39, 52]) the target is 63
# when input is tensor([50, 39, 52, 63]) the target is 1
# when input is tensor([50, 39, 52, 63,  1]) the target is 47
# when input is tensor([50, 39, 52, 63,  1, 47]) the target is 58
# when input is tensor([50, 39, 52, 63,  1, 47, 58]) the target is 57
# when input is tensor([50, 39, 52, 63,  1, 47, 58, 57]) the target is 43
# when input is tensor([56]) the target is 53
# when input is tensor([56, 53]) the target is 63
# when input is tensor([56, 53, 63]) the target is 1
# when input is tensor([56, 53, 63,  1]) the target is 42
# when input is tensor([56, 53, 63,  1, 42]) the target is 47
# when input is tensor([56, 53, 63,  1, 42, 47]) the target is 42
# when input is tensor([56, 53, 63,  1, 42, 47, 42]) the target is 1
# when input is tensor([56, 53, 63,  1, 42, 47, 42,  1]) the target is 57
# when input is tensor([39]) the target is 51
# when input is tensor([39, 51]) the target is 1
# when input is tensor([39, 51,  1]) the target is 39
# when input is tensor([39, 51,  1, 39]) the target is 44
# when input is tensor([39, 51,  1, 39, 44]) the target is 56
# when input is tensor([39, 51,  1, 39, 44, 56]) the target is 39
# when input is tensor([39, 51,  1, 39, 44, 56, 39]) the target is 47
# when input is tensor([39, 51,  1, 39, 44, 56, 39, 47]) the target is 42
# when input is tensor([17]) the target is 24
# when input is tensor([17, 24]) the target is 21
# when input is tensor([17, 24, 21]) the target is 38
# when input is tensor([17, 24, 21, 38]) the target is 13
# when input is tensor([17, 24, 21, 38, 13]) the target is 14
# when input is tensor([17, 24, 21, 38, 13, 14]) the target is 17
# when input is tensor([17, 24, 21, 38, 13, 14, 17]) the target is 32
# when input is tensor([17, 24, 21, 38, 13, 14, 17, 32]) the target is 20
# when input is tensor([1]) the target is 39
# when input is tensor([ 1, 39]) the target is 52
# when input is tensor([ 1, 39, 52]) the target is 42
# when input is tensor([ 1, 39, 52, 42]) the target is 1
# when input is tensor([ 1, 39, 52, 42,  1]) the target is 45
# when input is tensor([ 1, 39, 52, 42,  1, 45]) the target is 43
# when input is tensor([ 1, 39, 52, 42,  1, 45, 43]) the target is 50
# when input is tensor([ 1, 39, 52, 42,  1, 45, 43, 50]) the target is 42
# when input is tensor([1]) the target is 58
# when input is tensor([ 1, 58]) the target is 46
# when input is tensor([ 1, 58, 46]) the target is 39
# when input is tensor([ 1, 58, 46, 39]) the target is 58
# when input is tensor([ 1, 58, 46, 39, 58]) the target is 1
# when input is tensor([ 1, 58, 46, 39, 58,  1]) the target is 42
# when input is tensor([ 1, 58, 46, 39, 58,  1, 42]) the target is 53
# when input is tensor([ 1, 58, 46, 39, 58,  1, 42, 53]) the target is 1
# when input is tensor([1]) the target is 61
# when input is tensor([ 1, 61]) the target is 53
# when input is tensor([ 1, 61, 53]) the target is 59
# when input is tensor([ 1, 61, 53, 59]) the target is 50
# when input is tensor([ 1, 61, 53, 59, 50]) the target is 42
# when input is tensor([ 1, 61, 53, 59, 50, 42]) the target is 1
# when input is tensor([ 1, 61, 53, 59, 50, 42,  1]) the target is 21
# when input is tensor([ 1, 61, 53, 59, 50, 42,  1, 21]) the target is 1
# when input is tensor([59]) the target is 57
# when input is tensor([59, 57]) the target is 40
# when input is tensor([59, 57, 40]) the target is 39
# when input is tensor([59, 57, 40, 39]) the target is 52
# when input is tensor([59, 57, 40, 39, 52]) the target is 42
# when input is tensor([59, 57, 40, 39, 52, 42]) the target is 1
# when input is tensor([59, 57, 40, 39, 52, 42,  1]) the target is 40
# when input is tensor([59, 57, 40, 39, 52, 42,  1, 40]) the target is 47
# when input is tensor([52]) the target is 42
# when input is tensor([52, 42]) the target is 8
# when input is tensor([52, 42,  8]) the target is 0
# when input is tensor([52, 42,  8,  0]) the target is 0
# when input is tensor([52, 42,  8,  0,  0]) the target is 23
# when input is tensor([52, 42,  8,  0,  0, 23]) the target is 21
# when input is tensor([52, 42,  8,  0,  0, 23, 21]) the target is 26
# when input is tensor([52, 42,  8,  0,  0, 23, 21, 26]) the target is 19
# when input is tensor([45]) the target is 53
# when input is tensor([45, 53]) the target is 42
# when input is tensor([45, 53, 42]) the target is 57
# when input is tensor([45, 53, 42, 57]) the target is 0
# when input is tensor([45, 53, 42, 57,  0]) the target is 23
# when input is tensor([45, 53, 42, 57,  0, 23]) the target is 43
# when input is tensor([45, 53, 42, 57,  0, 23, 43]) the target is 43
# when input is tensor([45, 53, 42, 57,  0, 23, 43, 43]) the target is 54
# when input is tensor([52]) the target is 1
# when input is tensor([52,  1]) the target is 61
# when input is tensor([52,  1, 61]) the target is 39
# when input is tensor([52,  1, 61, 39]) the target is 57
# when input is tensor([52,  1, 61, 39, 57]) the target is 1
# when input is tensor([52,  1, 61, 39, 57,  1]) the target is 51
# when input is tensor([52,  1, 61, 39, 57,  1, 51]) the target is 53
# when input is tensor([52,  1, 61, 39, 57,  1, 51, 53]) the target is 56
# when input is tensor([39]) the target is 49
# when input is tensor([39, 49]) the target is 12
# when input is tensor([39, 49, 12]) the target is 1
# when input is tensor([39, 49, 12,  1]) the target is 27
# when input is tensor([39, 49, 12,  1, 27]) the target is 1
# when input is tensor([39, 49, 12,  1, 27,  1]) the target is 58
# when input is tensor([39, 49, 12,  1, 27,  1, 58]) the target is 56
# when input is tensor([39, 49, 12,  1, 27,  1, 58, 56]) the target is 39
# when input is tensor([53]) the target is 44
# when input is tensor([53, 44]) the target is 1
# when input is tensor([53, 44,  1]) the target is 57
# when input is tensor([53, 44,  1, 57]) the target is 54
# when input is tensor([53, 44,  1, 57, 54]) the target is 43
# when input is tensor([53, 44,  1, 57, 54, 43]) the target is 43
# when input is tensor([53, 44,  1, 57, 54, 43, 43]) the target is 41
# when input is tensor([53, 44,  1, 57, 54, 43, 43, 41]) the target is 46
# when input is tensor([57]) the target is 53
# when input is tensor([57, 53]) the target is 52
# when input is tensor([57, 53, 52]) the target is 57
# when input is tensor([57, 53, 52, 57]) the target is 8
# when input is tensor([57, 53, 52, 57,  8]) the target is 0
# when input is tensor([57, 53, 52, 57,  8,  0]) the target is 0
# when input is tensor([57, 53, 52, 57,  8,  0,  0]) the target is 25
# when input is tensor([57, 53, 52, 57,  8,  0,  0, 25]) the target is 17
# when input is tensor([1]) the target is 42
# when input is tensor([ 1, 42]) the target is 43
# when input is tensor([ 1, 42, 43]) the target is 44
# when input is tensor([ 1, 42, 43, 44]) the target is 43
# when input is tensor([ 1, 42, 43, 44, 43]) the target is 41
# when input is tensor([ 1, 42, 43, 44, 43, 41]) the target is 58
# when input is tensor([ 1, 42, 43, 44, 43, 41, 58]) the target is 1
# when input is tensor([ 1, 42, 43, 44, 43, 41, 58,  1]) the target is 53
# when input is tensor([21]) the target is 1
# when input is tensor([21,  1]) the target is 61
# when input is tensor([21,  1, 61]) the target is 39
# when input is tensor([21,  1, 61, 39]) the target is 52
# when input is tensor([21,  1, 61, 39, 52]) the target is 42
# when input is tensor([21,  1, 61, 39, 52, 42]) the target is 43
# when input is tensor([21,  1, 61, 39, 52, 42, 43]) the target is 56
# when input is tensor([21,  1, 61, 39, 52, 42, 43, 56]) the target is 6
# when input is tensor([43]) the target is 43
# when input is tensor([43, 43]) the target is 51
# when input is tensor([43, 43, 51]) the target is 5
# when input is tensor([43, 43, 51,  5]) the target is 42
# when input is tensor([43, 43, 51,  5, 42]) the target is 1
# when input is tensor([43, 43, 51,  5, 42,  1]) the target is 40
# when input is tensor([43, 43, 51,  5, 42,  1, 40]) the target is 59
# when input is tensor([43, 43, 51,  5, 42,  1, 40, 59]) the target is 56
# when input is tensor([45]) the target is 50
# when input is tensor([45, 50]) the target is 63
# when input is tensor([45, 50, 63]) the target is 1
# when input is tensor([45, 50, 63,  1]) the target is 52
# when input is tensor([45, 50, 63,  1, 52]) the target is 53
# when input is tensor([45, 50, 63,  1, 52, 53]) the target is 61
# when input is tensor([45, 50, 63,  1, 52, 53, 61]) the target is 12
# when input is tensor([45, 50, 63,  1, 52, 53, 61, 12]) the target is 0
# when input is tensor([52]) the target is 53
# when input is tensor([52, 53]) the target is 58
# when input is tensor([52, 53, 58]) the target is 8
# when input is tensor([52, 53, 58,  8]) the target is 0
# when input is tensor([52, 53, 58,  8,  0]) the target is 25
# when input is tensor([52, 53, 58,  8,  0, 25]) the target is 63
# when input is tensor([52, 53, 58,  8,  0, 25, 63]) the target is 1
# when input is tensor([52, 53, 58,  8,  0, 25, 63,  1]) the target is 61
# when input is tensor([53]) the target is 58
# when input is tensor([53, 58]) the target is 6
# when input is tensor([53, 58,  6]) the target is 1
# when input is tensor([53, 58,  6,  1]) the target is 51
# when input is tensor([53, 58,  6,  1, 51]) the target is 63
# when input is tensor([53, 58,  6,  1, 51, 63]) the target is 1
# when input is tensor([53, 58,  6,  1, 51, 63,  1]) the target is 50
# when input is tensor([53, 58,  6,  1, 51, 63,  1, 50]) the target is 53

# %%
yb.is_cuda
# Out:
# False

# %%
import torch 
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        # self.position_embedding_table = nn.Embedding(block_size, n_embd) # include the character position
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B,T = idx.shape
        
        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        # pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        # x = tok_emb + pos_emb # (B,T,C)
        # logits = self.lm_head(x) # (B,T,vocab_size)
        logits = self.lm_head(tok_emb)

        if targets is None:
            loss = None
        else:
            # because the second dimension of cross_entorpy represents the channels
            # we need to reshape the logits and targets
            B,T,C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss
    
    def generate(self, idx, max_new_tokens):

        # idx is (B,T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self.forward(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # become (B,C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B,C)
            # sample from the distribution
            next_tokens = torch.multinomial(probs, num_samples=1) # (B,1)
            # append smapled index to the running sequence
            idx = torch.cat([idx, next_tokens], dim=-1) # (B,T+1)

        return idx
    
model = BigramLanguageModel()
model = model.to(device)
logits, loss = model(xb, yb)
print(logits.shape)
print(loss)
start_idx = torch.zeros((1,1), dtype=torch.long).to(device)
print(decode(model.generate(start_idx, max_new_tokens=100)[0].tolist()))
# beacuse the model is not trained yet, the output is random
# also, we only focus on the last time step, did not consider the history
# Out:
# torch.Size([256, 65])
# tensor(4.3727, grad_fn=<NllLossBackward0>)
#
# HPlMBWro;w;UATy!dSD3UHrRygABctWrwezjJ-JyYkez kvlVuD;&YjT bl.K?;HoXSHWtwSoGsXXa-.?DuMm3ylY?DRijBqR;VR

# %%
model.generate(start_idx, max_new_tokens=100)[0].tolist()
# Out:
# [0,
#  13,
#  45,
#  2,
#  13,
#  39,
#  60,
#  6,
#  19,
#  57,
#  34,
#  40,
#  20,
#  42,
#  49,
#  27,
#  38,
#  36,
#  20,
#  47,
#  14,
#  63,
#  3,
#  32,
#  3,
#  44,
#  58,
#  49,
#  32,
#  17,
#  42,
#  12,
#  20,
#  28,
#  9,
#  64,
#  63,
#  31,
#  13,
#  43,
#  58,
#  57,
#  27,
#  15,
#  46,
#  20,
#  28,
#  7,
#  38,
#  64,
#  42,
#  57,
#  51,
#  35,
#  48,
#  47,
#  5,
#  57,
#  0,
#  40,
#  64,
#  13,
#  3,
#  48,
#  32,
#  30,
#  0,
#  42,
#  63,
#  16,
#  33,
#  60,
#  33,
#  6,
#  20,
#  38,
#  54,
#  52,
#  64,
#  58,
#  7,
#  30,
#  59,
#  13,
#  34,
#  39,
#  55,
#  6,
#  57,
#  52,
#  63,
#  50,
#  42,
#  45,
#  8,
#  27,
#  26,
#  57,
#  36,
#  19,
#  36]

# %%
# create optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval() # change to eval mode
    for split in ['train', 'valid']:
        losses = torch.zeros(eval_interval)
        for k in range(eval_interval):
            x, y = get_batch(split)
            logits, loss = model(x,y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()

    return out

# %%
for steps in range(max_iters):

    # every once in a while evaluate the loss on train and val loss
    if steps % eval_interval == 0:
        losses = estimate_loss()
        print(f"step: {steps}, train loss: {losses['train']:.4f}, val loss: {losses['valid']:.4f}")
        
    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

print(loss.item())
# Out:
# step: 0, train loss: 4.3391, val loss: 4.3362
# step: 1000, train loss: 2.4851, val loss: 2.5137
# step: 2000, train loss: 2.4850, val loss: 2.5183
# step: 3000, train loss: 2.4790, val loss: 2.5218
# step: 4000, train loss: 2.4758, val loss: 2.4987
# step: 5000, train loss: 2.4699, val loss: 2.5050
# step: 6000, train loss: 2.4763, val loss: 2.5090
# step: 7000, train loss: 2.4742, val loss: 2.4936
# step: 8000, train loss: 2.4723, val loss: 2.5128
# step: 9000, train loss: 2.4728, val loss: 2.5128
# step: 10000, train loss: 2.4792, val loss: 2.4988
# step: 11000, train loss: 2.4740, val loss: 2.5024
# step: 12000, train loss: 2.4723, val loss: 2.4989
# step: 13000, train loss: 2.4722, val loss: 2.4999
# step: 14000, train loss: 2.4728, val loss: 2.5017
# step: 15000, train loss: 2.4696, val loss: 2.5052
# step: 16000, train loss: 2.4742, val loss: 2.4976
# step: 17000, train loss: 2.4699, val loss: 2.4942
# step: 18000, train loss: 2.4701, val loss: 2.5049
# step: 19000, train loss: 2.4690, val loss: 2.4988
# step: 20000, train loss: 2.4717, val loss: 2.4972
# step: 21000, train loss: 2.4680, val loss: 2.5022
# step: 22000, train loss: 2.4721, val loss: 2.5024
# step: 23000, train loss: 2.4702, val loss: 2.4923
# step: 24000, train loss: 2.4689, val loss: 2.4909
# step: 25000, train loss: 2.4661, val loss: 2.4949
# step: 26000, train loss: 2.4680, val loss: 2.4990
# step: 27000, train loss: 2.4671, val loss: 2.4984
# step: 28000, train loss: 2.4671, val loss: 2.4950
# step: 29000, train loss: 2.4669, val loss: 2.4974
# step: 30000, train loss: 2.4651, val loss: 2.5006
# step: 31000, train loss: 2.4652, val loss: 2.4925
# step: 32000, train loss: 2.4613, val loss: 2.4987
# step: 33000, train loss: 2.4669, val loss: 2.4954
# step: 34000, train loss: 2.4669, val loss: 2.5010
# step: 35000, train loss: 2.4654, val loss: 2.4930
# step: 36000, train loss: 2.4644, val loss: 2.4942
# step: 37000, train loss: 2.4644, val loss: 2.4882
# step: 38000, train loss: 2.4695, val loss: 2.4883
# step: 39000, train loss: 2.4695, val loss: 2.4977
# step: 40000, train loss: 2.4687, val loss: 2.4922
# step: 41000, train loss: 2.4693, val loss: 2.4920
# step: 42000, train loss: 2.4643, val loss: 2.4947
# step: 43000, train loss: 2.4686, val loss: 2.4947
# step: 44000, train loss: 2.4615, val loss: 2.4906
# step: 45000, train loss: 2.4651, val loss: 2.4955
# step: 46000, train loss: 2.4665, val loss: 2.4974
# step: 47000, train loss: 2.4669, val loss: 2.4917
# step: 48000, train loss: 2.4646, val loss: 2.4982
# step: 49000, train loss: 2.4662, val loss: 2.4893
# 2.531035900115967

# %%
print(decode(model.generate(start_idx, max_new_tokens=400)[0].tolist()))
# characters are not talk to each other
# Out:
# Alorn. I ann
# A f whenes inghesche FR us.'d louthis cet this;
# AUCE:
# ARY:
# Se,---weaxt thorye y lur cr thy.
# brst ts wim nd.
# Rownsam t, bend yodeanfutheloneswe wndy. th cco we haper ipl ilioovith r.' f
# TO,
# Beeancit afow wor,
# Prd
# Two wate, mar obers atold d y, spou hal d:
# INRK:
# Angred t o y'd, afry wa S:
# Byafe'l p sharindistucencorglin!
# Rothoue ar, al by owhar;
# Tofrstithaughemouthos hefof pllyomanch th
